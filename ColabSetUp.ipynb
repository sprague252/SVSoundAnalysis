# %% [markdown]
# # Set Up SVSoundAnalysis in Google Colab

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/sprague252/SVSoundAnalysis/blob/master/ColabSetUp.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# This notebook contains the commands needed to import and run the SVSoundAnalysis example on Google Colab.
#
# All the files you need for SVSoundAnalysis are on GitHub at https://github.com/sprague252/SVSoundAnalysis. In order to use them on Colab, we need to connect your Google Drive and then clone the files from GitHub to your drive. Once you have done this, you can run the notebooks directly from your Google Drive.
#
# If you are already running this notebook in Cloab, skip to the next section, and run all the commands. If you are not running this notebook in Cloab, click on the Open in Colab button just below the title above to open it in Colab and get started.

# %% [markdown]
# ## 1. Connect your Google Drive

# %% [markdown]
# Run the following command to connect this notebook to your Google Drive. Note that you can run the code in a cell by selecting the cell and pressing `shift-enter` or by bressing the triangle-shaped "play" button in the cell.
#
# An authorzation window will open asking for permission. You must grant this to continue.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## 2. Pull SVSoundAnalysis files from GitHub

# %% [markdown]
# Now we will go to the top directory in your Google Drive and clone the SVSoundAnalysis repository fom GitHub into it. This will create a new directory in your Google Drive named `SVSoundAnalysis` with all of the files in the GitHub repository in it. Do this by entering the commands in the following cell.
#
# Note that you will get an error if you already have a directory named `SVSoundAnalysis`. To start over with a fresh copy of the repository delete or move the existing `SVSoundAnalysis` directory before running the command.

# %%
# %cd /content/gdrive/MyDrive
! git clone https://github.com/sprague252/SVSoundAnalysis.git

# %% [markdown]
# Now you are ready to run the SVSoundAnalysis notebooks in Colab. Go you your Google Drive and open one of the Jupyter Notebook files (they end in `.ipynb`) and run the cells in it. Each notebook has a Colab version and an version to use outside of Colab. The difference is the Colab version includes commands to install the packages not included on Colab by default.
